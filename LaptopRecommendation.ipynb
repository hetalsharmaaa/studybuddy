# %% [markdown]
# <a href="https://colab.research.google.com/github/hetalsharmaaa/QuickBrief/blob/main/LaptopRecommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pandas numpy scikit-learn scipy matplotlib seaborn
